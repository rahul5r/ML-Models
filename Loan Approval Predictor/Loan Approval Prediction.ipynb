# %% [markdown]
# #### **Load the dataset**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("loan_approval_dataset.csv")
df.head()
# Out:
#    loan_id  no_of_dependents    education self_employed  income_annum  \
# 0        1                 2     Graduate            No       9600000
# 1        2                 0  NotGraduate           Yes       4100000
# 2        3                 3     Graduate            No       9100000
# 3        4                 3     Graduate            No       8200000
# 4        5                 5  NotGraduate           Yes       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     29900000         12          778                   2400000
# 1     12200000          8          417                   2700000
# 2     29700000         20          506                   7100000
# 3     30700000          8          467                  18200000
# 4     24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value loan_status
# ...

# %%
df.isnull().sum()
# Out:
# loan_id                     0
# no_of_dependents            0
# education                   0
# self_employed               0
# income_annum                0
# loan_amount                 0
# loan_term                   0
# cibil_score                 0
# residential_assets_value    0
# commercial_assets_value     0
# luxury_assets_value         0
# bank_asset_value            0
# loan_status                 0
# dtype: int64

# %%
df["education"] = df["education"].replace({'Graduate': 1, 'NotGraduate': 0})
df["self_employed"] = df["self_employed"].replace({'Yes': 1, 'No': 0})
df["loan_status"] = df["loan_status"].replace({'Approved': 1, 'Rejected': 0})
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_22780\2426566520.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["education"] = df["education"].replace({'Graduate': 1, 'NotGraduate': 0})
# C:\Users\rahul\AppData\Local\Temp\ipykernel_22780\2426566520.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["self_employed"] = df["self_employed"].replace({'Yes': 1, 'No': 0})
# ...

# %%
columns = ["income_annum", "loan_amount", "residential_assets_value", "commercial_assets_value", "luxury_assets_value", "bank_asset_value"]
normalization_factors = {}

for col in columns:
    normalization_factors[col] = max(df[col])
    df[col] = df[col]/max(df[col])

# %%
df.head()
# Out:
#    loan_id  no_of_dependents  education  self_employed  income_annum  \
# 0        1                 2          1              0      0.969697
# 1        2                 0          0              1      0.414141
# 2        3                 3          1              0      0.919192
# 3        4                 3          1              0      0.828283
# 4        5                 5          0              1      0.989899
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     0.756962         12          778                  0.082474
# 1     0.308861          8          417                  0.092784
# 2     0.751899         20          506                  0.243986
# 3     0.777215          8          467                  0.625430
# 4     0.612658         20          382                  0.426117
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value  loan_status
# 0                 0.907216             0.579082          0.544218            1
# ...

# %%
X = df.drop(['loan_id', 'loan_status'], axis=1)
y = df['loan_status']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
print(X_train.loc[1])
print(y_train.loc[1])
# Out:
# no_of_dependents              0.000000
# education                     0.000000
# self_employed                 1.000000
# income_annum                  0.414141
# loan_amount                   0.308861
# loan_term                     8.000000
# cibil_score                 417.000000
# residential_assets_value      0.092784
# commercial_assets_value       0.113402
# luxury_assets_value           0.224490
# bank_asset_value              0.224490
# Name: 1, dtype: float64
# 0

# %%
X_train.describe()
# Out:
#        no_of_dependents    education  self_employed  income_annum  \
# count       2860.000000  2860.000000    2860.000000   2860.000000
# mean           2.411538     0.503846       0.509441      0.512492
# std            1.686585     0.500073       0.499998      0.284505
# min            0.000000     0.000000       0.000000      0.020202
# 25%            1.000000     0.000000       0.000000      0.262626
# 50%            2.000000     1.000000       1.000000      0.515152
# 75%            4.000000     1.000000       1.000000      0.757576
# max            5.000000     1.000000       1.000000      1.000000
#
#        loan_amount    loan_term  cibil_score  residential_assets_value  \
# count  2860.000000  2860.000000  2860.000000               2860.000000
# mean      0.384322    11.045455   601.216084                  0.257214
# std       0.229452     5.723673   173.083680                  0.225480
# min       0.007595     2.000000   300.000000                 -0.003436
# ...

# %%
from sklearn.linear_model import  LogisticRegression

logistic_model = LogisticRegression(max_iter=10000, random_state=42)

# %%
logistic_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000, random_state=42)

# %%
logistic_model.score(X_test, y_test)
# Out:
# 0.9112845990063875

# %%
normalization_factors
# Out:
# {'income_annum': 9900000,
#  'loan_amount': 39500000,
#  'residential_assets_value': 29100000,
#  'commercial_assets_value': 19400000,
#  'luxury_assets_value': 39200000,
#  'bank_asset_value': 14700000}

# %% [markdown]
# #### **Saving the Model**

# %%
import pickle

with open('LoanApprovalPrediction_Model.pkl', 'wb') as f:
    pickle.dump(logistic_model, f)

# %% [markdown]
# #### **Loading the Model**

# %%
from joblib import load
import numpy as np 

model = load("LoanApprovalPrediction_Model.pkl")

# %%
df.loc[2]
# Out:
# loan_id                       3.000000
# no_of_dependents              3.000000
# education                     1.000000
# self_employed                 0.000000
# income_annum                  0.919192
# loan_amount                   0.751899
# loan_term                    20.000000
# cibil_score                 506.000000
# residential_assets_value      0.243986
# commercial_assets_value       0.231959
# luxury_assets_value           0.849490
# bank_asset_value              0.870748
# loan_status                   0.000000
# Name: 2, dtype: float64

# %%
# 3710,3,Graduate,No,4100000,11700000,10,729,6900000,6200000,15400000,2100000,Approved
# 3711,5,NotGraduate,Yes,4500000,12700000,8,307,11000000,3800000,12600000,2700000,Rejected

""" 
sample = {
    'no_of_dependents': 3, 
    'education': 1, 
    'self_employed': 0,   
    'income_annum': 4100000, 
    'loan_amount': 11700000,
    'loan_term': 10, 
    'cibil_score': 729,   
    'residential_assets_value': 6900000, 
    'commercial_assets_value': 6200000,
    'luxury_assets_value': 15400000, 
    'bank_asset_value': 2100000
}
"""
sample = {
    'no_of_dependents': 5, 
    'education': 0, 
    'self_employed': 1,   
    'income_annum': 4500000, 
    'loan_amount': 12700000,
    'loan_term': 8, 
    'cibil_score': 307,   
    'residential_assets_value': 11000000, 
    'commercial_assets_value': 3800000,
    'luxury_assets_value': 12600000, 
    'bank_asset_value': 2700000
}

# %%
normalization_factors
# Out:
# {'income_annum': 9900000,
#  'loan_amount': 39500000,
#  'residential_assets_value': 29100000,
#  'commercial_assets_value': 19400000,
#  'luxury_assets_value': 39200000,
#  'bank_asset_value': 14700000}

# %%
for factor, value in normalization_factors.items():
    sample[factor] = sample[factor]/value

# %%
sample
# Out:
# {'no_of_dependents': 5,
#  'education': 0,
#  'self_employed': 1,
#  'income_annum': 0.45454545454545453,
#  'loan_amount': 0.32151898734177214,
#  'loan_term': 8,
#  'cibil_score': 307,
#  'residential_assets_value': 0.37800687285223367,
#  'commercial_assets_value': 0.1958762886597938,
#  'luxury_assets_value': 0.32142857142857145,
#  'bank_asset_value': 0.1836734693877551}

# %%
sample_values = np.array(list(sample.values())).reshape(1, -1)

# %%
model.predict(sample_values)
# Out:
# C:\Users\rahul\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
